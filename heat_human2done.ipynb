# %% [markdown]
# <a href="https://colab.research.google.com/github/Erandi-Apsara/Line-Follower-Robot_Arduino/blob/main/heat_human2done.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/MyDrive/thermal_dataset')

# %%
# !unzip heat_detection.zip -d heat_detection
# Out:
# Archive:  heat_detection.zip
#   inflating: heat_detection/README.dataset.txt
#   inflating: heat_detection/README.roboflow.txt
#   inflating: heat_detection/data.yaml
#    creating: heat_detection/test/
#    creating: heat_detection/test/images/
#  extracting: heat_detection/test/images/0018_jpg.rf.0203cf3789e05383270cac11760de8e9.jpg
#  extracting: heat_detection/test/images/0103_jpg.rf.cdc01e2b2ce7b483b7cf5f92c27834ab.jpg
#  extracting: heat_detection/test/images/0201_jpg.rf.d0bedd923af0f3f33f49d8132e22a104.jpg
#  extracting: heat_detection/test/images/0251_jpg.rf.9c61dbeb276ba6043bcdc2310e3b1c6f.jpg
#  extracting: heat_detection/test/images/0308_jpg.rf.46764a1c17c517288652c12a54e0fb08.jpg
#  extracting: heat_detection/test/images/0315_jpg.rf.16881999f5246306fd6a916671b97c48.jpg
#  extracting: heat_detection/test/images/0359_jpg.rf.69fa7b5f243f6496022ad81e2cab4d2f.jpg
#  extracting: heat_detection/test/images/0387_jpg.rf.3218212549ac2f65599345b6e08606b9.jpg
# ...

# %%
# !pip install torch torchvision torchaudio
# !pip install matplotlib
# !pip install numpy
# !pip install opencv-python
# !pip install pycocotools
# !pip install git+https://github.com/ultralytics/yolov5.git
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 104.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 51.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 77.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
# ...

# %%
# !pip install -U setuptools
# !pip install -U wheel
# !pip install -U cython
# !pip install -U numpy
# Out:
# ...
#   Using cached setuptools-80.3.0-py3-none-any.whl.metadata (6.5 kB)
# Using cached setuptools-80.3.0-py3-none-any.whl (1.2 MB)
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 85.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ...

# %%
# !pip install numpy==1.21.6
# Out:
# ERROR: Ignored the following versions that require a different python version: 1.21.2 Requires-Python >=3.7,<3.11; 1.21.3 Requires-Python >=3.7,<3.11; 1.21.4 Requires-Python >=3.7,<3.11; 1.21.5 Requires-Python >=3.7,<3.11; 1.21.6 Requires-Python >=3.7,<3.11
# ...

# %%
# Clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5

# Install requirements
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.29 MiB | 22.28 MiB/s, done.
# Resolving deltas: 100% (11929/11929), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 18.6 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip /content/drive/MyDrive/thermal_dataset/heat_detection.zip -d /content/thermal_dataset
# Out:
# Archive:  /content/drive/MyDrive/thermal_dataset/heat_detection.zip
#   inflating: /content/thermal_dataset/README.dataset.txt
#   inflating: /content/thermal_dataset/README.roboflow.txt
#   inflating: /content/thermal_dataset/data.yaml
#    creating: /content/thermal_dataset/test/
#    creating: /content/thermal_dataset/test/images/
#  extracting: /content/thermal_dataset/test/images/0018_jpg.rf.0203cf3789e05383270cac11760de8e9.jpg
#  extracting: /content/thermal_dataset/test/images/0103_jpg.rf.cdc01e2b2ce7b483b7cf5f92c27834ab.jpg
#  extracting: /content/thermal_dataset/test/images/0201_jpg.rf.d0bedd923af0f3f33f49d8132e22a104.jpg
#  extracting: /content/thermal_dataset/test/images/0251_jpg.rf.9c61dbeb276ba6043bcdc2310e3b1c6f.jpg
#  extracting: /content/thermal_dataset/test/images/0308_jpg.rf.46764a1c17c517288652c12a54e0fb08.jpg
#  extracting: /content/thermal_dataset/test/images/0315_jpg.rf.16881999f5246306fd6a916671b97c48.jpg
# ...

# %%
dataset_yaml = """
train: /content/thermal_dataset/images/train
val: /content/thermal_dataset/images/val

nc: 1
names: ['person']
"""

with open("thermal.yaml", "w") as f:
    f.write(dataset_yaml)

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data thermal.yaml --weights yolov5s.pt --cache
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-04 14:01:04.017397: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746367264.311117    8193 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !ls /content/thermal_dataset/images
# !ls /content/thermal_dataset/images/val
# Out:
# ls: cannot access '/content/thermal_dataset/images': No such file or directory
# ls: cannot access '/content/thermal_dataset/images/val': No such file or directory

# %%
# !ls /content
# Out:
# drive  sample_data  thermal_dataset  yolov5

# %%
# !ls /content/thermal_dataset
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
yaml_content = """
train: /content/thermal_dataset/train/images  # Path to training images
val: /content/thermal_dataset/valid/images    # Path to validation images

test: /content/thermal_dataset/test/images    # Optional: Path to test images

nc: 1  # Number of classes, adjust this based on your dataset (e.g., 1 for 'person')
names: ['person']  # List of class names, update this to match your dataset
"""

# Write to the thermal.yaml file
with open('/content/thermal_dataset/data.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !ls /content/thermal_dataset/
# Out:
# images	labels

# %%
# !ls /content/thermal_dataset/valid
# Out:
# images	labels

# %%
yaml_content = """
train: /content/thermal_dataset/train/images  # Path to training images
val: /content/thermal_dataset/valid/images    # Path to validation images

test: /content/thermal_dataset/test/images    # Optional: Path to test images

nc: 1  # Number of classes, adjust this based on your dataset (e.g., 1 for 'person')
names: ['person']  # List of class names, update this to match your dataset
"""

# Write to the thermal.yaml file
with open('/content/thermal_dataset/data.yaml', 'w') as f:
    f.write(yaml_content)

# %%
# !python train.py --img 640 --batch-size 16 --epochs 50 --data /content/thermal_dataset/data.yaml --weights yolov5s.pt --device 0
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-04 14:08:10.544183: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746367690.578958    9998 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746367690.588907    9998 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !python train.py --img 640 --batch-size 16 --epochs 50 --data /content/thermal_dataset/data.yaml --weights yolov5s.pt --device cpu
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-04 14:10:03.736773: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746367803.762198   10499 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746367803.769606   10499 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !python train.py --resume --device cpu
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-04 15:13:30.046913: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746371610.371085   25713 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746371610.460133   25713 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# %cd /content/yolov5
# Out:
# [Errno 2] No such file or directory: '/content/yolov5'
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.30 MiB | 20.66 MiB/s, done.
# Resolving deltas: 100% (11935/11935), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 106.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 77.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 95.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 54.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --resume --device cpu
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 02:25:55.665261: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746411955.943042    1415 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch-size 16 --epochs 50 --data /content/thermal_dataset/data.yaml --weights yolov5s.pt --device cpu
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 03:03:09.692770: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746414190.069386   10371 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746414190.182686   10371 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !ls /content
# Out:
# sample_data  yolov5

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content/drive/MyDrive/thermal_dataset
# Out:
# heat_detection	heat_detection.zip

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !cp -r /content/drive/MyDrive/thermal_dataset/heat_detection /content/thermal_dataset

# %%
data_yaml = """
train: /content/thermal_dataset/train/images
val: /content/thermal_dataset/valid/images
test: /content/thermal_dataset/test/images

nc: 1
names: ['person']
"""
with open('/content/thermal_dataset/data.yaml', 'w') as f:
    f.write(data_yaml)

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/thermal_dataset/data.yaml --weights yolov5s.pt --name thermal_yolov5
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 03:12:13.637600: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746414733.670257   16669 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746414733.678291   16669 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# %cd /content/yolov5
# Out:
# [Errno 2] No such file or directory: '/content/yolov5'
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.30 MiB | 19.19 MiB/s, done.
# Resolving deltas: 100% (11935/11935), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# %pip install -r requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 68.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 36.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 106.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 69.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/thermal_dataset/data.yaml --weights yolov5s.pt --name thermal_yolov5
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 06:01:39.103472: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746424899.344358    1925 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --name thermal_yolov5
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 06:03:00.727281: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746424980.747020    2349 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746424980.752993    2349 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection
# Out:
# ls: cannot access '/content/drive/MyDrive/thermal_dataset/heat_detection': No such file or directory

# %%
# !ls /content/drive
# Out:
# ls: cannot access '/content/drive': No such file or directory

# %%
# !ls /content/drive/MyDrive/thermal_dataset
# Out:
# ls: cannot access '/content/drive/MyDrive/thermal_dataset': No such file or directory

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection
# Out:
# ls: cannot access '/content/drive/MyDrive/thermal_dataset/heat_detection': No such file or directory

# %%
ls: cannot access '/content/drive/MyDrive/thermal_dataset/heat_detection': No such file or directory
# Out:
# ls: cannot access ':': No such file or directory
# ls: cannot access 'cannot': No such file or directory
# ls: cannot access 'access': No such file or directory
# ls: cannot access '/content/drive/MyDrive/thermal_dataset/heat_detection:': No such file or directory
# ls: cannot access 'No': No such file or directory
# ls: cannot access 'such': No such file or directory
# ls: cannot access 'file': No such file or directory
# ls: cannot access 'or': No such file or directory
# ls: cannot access 'directory': No such file or directory

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection
# Out:
# ls: cannot access '/content/drive/MyDrive/thermal_dataset/heat_detection': No such file or directory

# %%
# !unzip /content/drive/MyDrive/thermal_dataset/heat_detection.zip -d /content/drive/MyDrive/thermal_dataset/
# Out:
# unzip:  cannot find or open /content/drive/MyDrive/thermal_dataset/heat_detection.zip, /content/drive/MyDrive/thermal_dataset/heat_detection.zip.zip or /content/drive/MyDrive/thermal_dataset/heat_detection.zip.ZIP.

# %%
# !ls -lh /content/drive/MyDrive/thermal_dataset/
# Out:
# ls: cannot access '/content/drive/MyDrive/thermal_dataset/': No such file or directory

# %%
from google.colab import drive
drive.flush_and_unmount()  # Safely unmount if previously mounted
# Out:
# Drive not mounted, so nothing to flush and unmount.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls -lh /content/drive/MyDrive/thermal_dataset/
# Out:
# total 95M
# drwx------ 2 root root 4.0K May  4 13:41 heat_detection
# -rw------- 1 root root  95M May  2 05:57 heat_detection.zip

# %%
# !ls -l /content/drive/MyDrive/thermal_dataset/heat_detection/
# Out:
# total 14
# -rw------- 1 root root  273 May  2 04:36 data.yaml
# -rw------- 1 root root  151 May  2 04:36 README.dataset.txt
# -rw------- 1 root root  972 May  2 04:36 README.roboflow.txt
# drwx------ 2 root root 4096 May  4 13:41 test
# drwx------ 2 root root 4096 May  4 13:41 train
# drwx------ 2 root root 4096 May  2 04:36 valid

# %%
# !cat /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml
# Out:
# train: ../train/images
# val: ../valid/images
# test: ../test/images
#
# nc: 1
# names: ['person']
#
# roboflow:
#   workspace: erandi-tsx4r
#   project: heat_detection-6bfgd
#   version: 1
#   license: CC BY 4.0
#   url: https://universe.roboflow.com/erandi-tsx4r/heat_detection-6bfgd/dataset/1

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/train
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/valid
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/test
# Out:
# images	labels
# images	labels
# images	labels

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/train/images
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/train/labels
# Out:
# frame-000019_jpg.rf.251ce8ffac8b2667205c7668c7076a27.jpg
# frame-000019_jpg.rf.6084a6e88f76e427ef5682f489d243c1.jpg
# frame-000020_jpg.rf.54f6ef7e6f89e44e65f4a479a7a60a88.jpg
# frame-000020_jpg.rf.657638f332a0c9e2aadc3bbb408c2f9c.jpg
# frame-000020_jpg.rf.a9d1577ddbf114c567328135376c3241.jpg
# frame-000020_jpg.rf.c66a5c2815dc519089b888c5513e0dd2.jpg
# frame-000020_jpg.rf.e94c7e3a49138179173ac73385e68a05.jpg
# frame-000021_jpg.rf.2d365c9bfb077a1d486a40d5c7b9ad8f.jpg
# frame-000021_jpg.rf.c07032f6f01e85e4b24dd153f5ff41df.jpg
# frame-000021_jpg.rf.c67e92446ef268dc56a17a59279e6871.jpg
# frame-000021_jpg.rf.f5c8e43a4658675582648db464ef3412.jpg
# frame-000021_jpg.rf.fc9659ad05ec3c621df676b10599dcd4.jpg
# frame-000022_jpg.rf.3fdf37bc9002666ee80540b0597e0a9d.jpg
# frame-000022_jpg.rf.4afc51a66474052195d68f5a5b10fefb.jpg
# frame-000022_jpg.rf.565e5688745cbc224c24835e1d67bca9.jpg
# frame-000022_jpg.rf.8e1594ba8982e911f6df7a652ff4aa9c.jpg
# ...

# %%
# !python /path/to/yolov5/train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --cache
# Out:
# python3: can't open file '/path/to/yolov5/train.py': [Errno 2] No such file or directory

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17413, done.
# remote: Counting objects: 100% (86/86), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 17413 (delta 64), reused 22 (delta 22), pack-reused 17327 (from 4)
# Receiving objects: 100% (17413/17413), 16.29 MiB | 17.77 MiB/s, done.
# Resolving deltas: 100% (11929/11929), done.

# %%
# %cd yolov5
# Out:
# /content/yolov5/yolov5

# %%
# !pip install -U -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 104.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 112.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.0/278.0 kB 27.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.2/865.2 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 393.1/393.1 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 135.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 97.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.7/897.7 kB 61.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 571.0/571.0 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.2/200.2 MB 6.1 MB/s eta 0:00:00
# ...

# %%
# !python3 train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --cache
# Out:
# python3: can't open file '/content/train.py': [Errno 2] No such file or directory

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python3 train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 06:23:06.451269: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746426186.471693    7863 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746426186.477822    7863 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
# !ls /content/drive/MyDrive/thermal_dataset/heat_detection/valid/images/
# Out:
# 0005_jpg.rf.60da99561cd7650f1704113a96d24ba7.jpg
# 0008_jpg.rf.779cc476faddc19b18c17043c8d60e14.jpg
# 0012_jpg.rf.5947212230698d5f19d2195c4b6fa005.jpg
# 0014_jpg.rf.897fba4fcbe7629a4aa756e79ad91c74.jpg
# 0016_jpg.rf.e431c5527873492a54a5da1626554833.jpg
# 001_jpg.rf.66eaa7e25c4be525e7cd8db05c69558f.jpg
# 0022_jpg.rf.ac36e66f639d01f813ccf8fcf320c47c.jpg
# 0024_jpg.rf.6f9a7cf713d1d265275f3fd82b07411b.jpg
# 0026_jpg.rf.3dd5b2cfa880294d6957c684a25d1e7b.jpg
# 0028_jpg.rf.88713f6e828579a398af7e77db489374.jpg
# 0032_jpg.rf.e0c80bac6b738c8427925c92b94731ba.jpg
# 0034_jpg.rf.cbfb350f84d90459100a1655a9f02100.jpg
# 0036_jpg.rf.39c4a7af4cc7b3b0c1d99e36d05747f3.jpg
# 0038_jpg.rf.7e61573f570f46dc0399e5b36550dc42.jpg
# 0042_jpg.rf.2d586ef7340c1df430c3243d28419615.jpg
# 0046_jpg.rf.c82a251ba680a5a08b8bc2b7e7396486.jpg
# 0048_jpg.rf.383d607652f52abc312e53d140e3c7de.jpg
# 0050_jpg.rf.782b73b177e1883c9509ffcab9ef855c.jpg
# 0053_jpg.rf.06b5783bb27129e4fed481965944a6fc.jpg
# ...

# %%
# !python3 train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-05-05 06:41:34.398584: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746427294.419447   12679 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746427294.425409   12679 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: (30 second timeout)
# ...

# %%
data_yaml_path = '/content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml'

# Write the correct absolute paths into the file
correct_data_yaml = """
train: /content/drive/MyDrive/thermal_dataset/heat_detection/train/images
val: /content/drive/MyDrive/thermal_dataset/heat_detection/valid/images
test: /content/drive/MyDrive/thermal_dataset/heat_detection/test/images

nc: 1
names: ['person']
"""

with open(data_yaml_path, 'w') as f:
    f.write(correct_data_yaml.strip())

print("✅ data.yaml updated successfully.")
# Out:
# ✅ data.yaml updated successfully.

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/drive/MyDrive/thermal_dataset/heat_detection/data.yaml --weights yolov5s.pt --cache
# Out:
# Streaming output truncated to the last 5000 lines.
#       23/49      4.24G    0.02333   0.009767          0         41        640:  61% 56/92 [00:15<00:08,  4.22it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/49      4.24G    0.02311   0.009753          0         35        640:  62% 57/92 [00:15<00:08,  4.23it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#       23/49      4.24G    0.02314   0.009715          0         34        640:  63% 58/92 [00:15<00:08,  4.08it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
# ...

# %%
from IPython.display import Image
Image(filename='runs/train/exp3/results.png', width=800)

# %%
Image(filename='runs/train/exp3/confusion_matrix.png', width=800)

# %%
Image(filename='runs/train/exp3/confusion_matrix.png', width=800)

# %%
# !ls /content/runs/train/exp3/weights/
# Out:
# ls: cannot access '/content/runs/train/exp3/weights/': No such file or directory

# %%
import os

# Search for any 'runs' folder in the environment
os.listdir('/content/')
# Out:
# ['.config', 'drive', 'yolov5', 'sample_data']

# %%
os.listdir('/content/yolov5')
# Out:
# ['pyproject.toml',
#  'CITATION.cff',
#  'README.zh-CN.md',
#  'tutorial.ipynb',
#  'yolov5s.pt',
#  'val.py',
#  'export.py',
#  '.git',
#  'segment',
#  'hubconf.py',
#  'models',
#  'data',
#  'CONTRIBUTING.md',
#  'detect.py',
#  '.gitignore',
#  '.github',
#  '.gitattributes',
#  'LICENSE',
#  '.dockerignore',
#  'classify',
#  'requirements.txt',
#  'README.md',
#  'utils',
#  'train.py',
#  'runs',
#  'benchmarks.py',
#  '__pycache__',
#  'yolov5']

# %%
os.listdir('/content/yolov5/runs')
# Out:
# ['detect', 'train']

# %%
os.listdir('/content/yolov5/runs/train')
# Out:
# ['exp3', 'exp2', 'exp']

# %%
os.listdir('/content/yolov5/runs/train/exp3')
# Out:
# ['R_curve.png',
#  'val_batch0_pred.jpg',
#  'labels_correlogram.jpg',
#  'results.png',
#  'hyp.yaml',
#  'confusion_matrix.png',
#  'val_batch2_pred.jpg',
#  'weights',
#  'val_batch0_labels.jpg',
#  'P_curve.png',
#  'val_batch1_labels.jpg',
#  'val_batch1_pred.jpg',
#  'F1_curve.png',
#  'train_batch2.jpg',
#  'events.out.tfevents.1746427478.fee5a9368c96.13371.0',
#  'train_batch0.jpg',
#  'opt.yaml',
#  'results.csv',
#  'train_batch1.jpg',
#  'labels.jpg',
#  'val_batch2_labels.jpg',
#  'PR_curve.png']

# %%
os.listdir('/content/yolov5/runs/train/exp3/weights')
# Out:
# ['best.pt', 'last.pt']

# %%
import shutil

# Copy the trained model files to Google Drive
shutil.copy('/content/yolov5/runs/train/exp3/weights/best.pt', '/content/drive/MyDrive/thermal_dataset/best.pt')
shutil.copy('/content/yolov5/runs/train/exp3/weights/last.pt', '/content/drive/MyDrive/thermal_dataset/last.pt')
# Out:
# '/content/drive/MyDrive/thermal_dataset/last.pt'

# %%
import shutil

# Copy the trained model to Google Drive
shutil.copy('/content/yolov5/runs/train/exp3/weights/last.pt', '/content/drive/MyDrive/thermal_dataset/last.pt')
# Out:
# '/content/drive/MyDrive/thermal_dataset/last.pt'

# %%
import shutil

# Copy to local Colab environment
shutil.copy('/content/yolov5/runs/train/exp3/weights/last.pt', '/content/last.pt')
shutil.copy('/content/yolov5/runs/train/exp3/weights/best.pt', '/content/best.pt')

# Copy to Google Drive
shutil.copy('/content/yolov5/runs/train/exp3/weights/last.pt', '/content/drive/MyDrive/thermal_dataset/last.pt')
shutil.copy('/content/yolov5/runs/train/exp3/weights/best.pt', '/content/drive/MyDrive/thermal_dataset/best.pt')
# Out:
# '/content/drive/MyDrive/thermal_dataset/best.pt'
